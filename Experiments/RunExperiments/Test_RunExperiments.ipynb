# %%
# %load_ext autoreload
# %autoreload 2

# %%
from PFNExperiments.Experiments.RunExperiments.RunExperiments import RunExperiments

# %%
config_path = r"C:\Users\arik_\Documents\Dokumente\Job_Clausthal\PFNs\Repository\PFNExperiments\Experiments\Configs\TestConfigs\test_config_v1.ini"

# %%
experiment = RunExperiments(config_path=config_path)

# %%
experiment.run()
# Out:
#                                                Model  GT  \
# 0  <PFNExperiments.LinearRegression.Models.ModelT...  gt
# 1  Variational Inference with guide: AutoDiagonal...  gt
# 2  Variational Inference with guide: AutoMultivar...  gt
#
#    Mean_joint_Wasserstein_distance with metric euclidean  Mean_joint_MMD  \
# 0                                           7.558353            0.845383
# 1                                           7.674500            0.874765
# 2                                           7.593807            0.829168
#
#    Mean_joint_cst_roc_auc  Mean_gt_parameter_Perplextiy  \
# 0                     NaN                     -6.536636
# 1                     NaN                    -15.228023
# 2                     NaN                     -7.093114
#
#    Mean_gt_parameter_MAP diff  Mean_gt_parameter_Mean diff  \
# 0                    0.666030                     0.712253
# 1                    0.516867                     0.531649
# ...
