# %%
# %load_ext autoreload
# %autoreload 2

# %%
from Quantizer import Quantizer
import torch

# %%
beta_vals = torch.rand(100, 100, 100)

# %%
quant = Quantizer(
    quantile_samples=beta_vals.flatten(),
    possible_bucket_numbers=[2**i for i in range(1, 10)]
)

# %%
quant.quantize(beta_vals, n_buckets=256)
# Out:
# tensor([[[3.5924e-01, 1.5655e-01, 1.1716e-02,  ..., 4.1772e-01,
#           1.8763e-01, 3.3965e-01],
#          [2.3842e-01, 7.9247e-01, 8.9798e-01,  ..., 3.6320e-01,
#           4.8412e-01, 2.1113e-01],
#          [9.4920e-01, 4.7232e-01, 2.8880e-01,  ..., 4.8798e-01,
#           6.3646e-01, 1.2120e-01],
#          ...,
#          [2.2288e-01, 9.7618e-02, 2.9656e-01,  ..., 3.3191e-01,
#           8.5891e-01, 2.0714e-01],
#          [3.5531e-01, 8.5891e-01, 6.9904e-01,  ..., 7.8464e-01,
#           2.1894e-01, 5.0762e-01],
#          [9.4920e-01, 7.3046e-01, 1.9555e-01,  ..., 1.5601e-02,
#           9.0583e-01, 2.2288e-01]],
#
#         [[9.6890e-01, 5.0371e-01, 6.8737e-01,  ..., 9.9616e-01,
#           3.2807e-01, 5.6632e-01],
#          [6.5996e-01, 2.5007e-01, 9.7277e-01,  ..., 3.2807e-01,
#           5.0653e-02, 8.7064e-01],
#          [5.2714e-01, 7.5395e-01, 4.8412e-01,  ..., 5.9363e-01,
#           2.8497e-01, 7.3821e-01],
#          ...,
# ...
